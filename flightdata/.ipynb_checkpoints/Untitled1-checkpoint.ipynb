# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import HTML,display

# %%
economy =  pd.read_csv('economy.csv')
business = pd.read_csv('business.csv')

# %%
business.head(4)
# Out:
#          date    airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  Air India      AI       868    18:00  Delhi    02h 00m
# 1  11-02-2022  Air India      AI       624    19:00  Delhi    02h 15m
# 2  11-02-2022  Air India      AI       531    20:00  Delhi    24h 45m
# 3  11-02-2022  Air India      AI       839    21:25  Delhi    26h 30m
#
#                                                 stop arr_time      to   price
# 0                                          non-stop     20:00  Mumbai  25,612
# 1                                          non-stop     21:15  Mumbai  25,612
# 2  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45  Mumbai  42,220
# 3  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55  Mumbai  44,450

# %%
economy
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
def stopsfind(stops): # "1-stop\n\t\t\" , "1-stop\n\t\tVia Vishakhapatnam\n\t\t\"    
    stops = stops.replace('Via','').split()
    if stops[0] == "1-stop":
            stops[0] = "one"
    elif stops[0] == "non-stop":
            stops[0] = "zero"
    else:
            stops[0] = "two_or_more"
    if len(stops) == 1:
        return pd.Series([stops[0],"NAN"])
    else:
        return pd.Series([stops[0],stops[1]])

# %%
economy[['stops','stops_via']] = economy['stop'].apply(stopsfind)

# %%
economy
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...

# %%
economy['stops'].value_counts()
# Out:
# one            166627
# zero            27942
# two_or_more     12205
# Name: stops, dtype: int64

# %%
def time_min(timming):
    timming = timming.replace('h','').replace('m','')
    
    if len(timming.split())==1:
        timming = timming.split('.')
    else:
        timming = timming.split()
        
    timming = int(timming[0])*60 + int(timming[1])

    return timming

# %%
economy['time_min']=economy['time_taken'].apply(time_min)

# %%
economy.head(2)
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
#
#         stop arr_time      to  price stops stops_via  time_min
# 0  non-stop     21:05  Mumbai  5,953  zero       NAN       130
# 1  non-stop     08:40  Mumbai  5,953  zero       NAN       140

# %%
economy['ch_code'][0] + "-" + str(economy['num_code'][0])
# Out:
# 'SG-8709'

# %%
def codemake(x,y):
    return x + "-" + str(y)

# %%
economy['flight']=economy[['ch_code','num_code']].apply(lambda x: codemake(*x),axis=1)

# %%
tmm = economy['dep_time'][0].split(":")
tmm[0]
# Out:
# '18'

# %%
# 4 - 7 early morning
# 7 - 12  morning
# 12 - 17 afternoon
# 17 - 20 evening
# 20 - 4 night

# %%
def deptime(tmm):
    tmm = int(tmm.split(":")[0])
    if tmm >= 7 and tmm <12:
        day = 'Morning'
    elif tmm >=12 and tmm<17:
        day = 'Afternoon'
    elif tmm >=17 and tmm<20:
        day = 'Evening'
    elif tmm >=20 and tmm <4:
        day = "Night"
    else:
        day = 'Early morning'
    return day

# %%
economy['departure_time'] = economy['dep_time'].apply(deptime)

# %%
economy['arrival_time'] = economy['arr_time'].apply(deptime)

# %%
economy['price'][0].replace(',','')
# Out:
# '5953'

# %%
economy['price'] = economy['price'].apply(lambda x: int(x.replace(',','')) )

# %%
economy
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
# ...
